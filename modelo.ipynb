# %%
import pandas as pd

# %%
df = pd.read_csv('dataset\VRA_20251.csv', skiprows=1, sep=';')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\V'
# <>:1: SyntaxWarning: invalid escape sequence '\V'
# C:\Users\Ebenezer Carvalho\AppData\Local\Temp\ipykernel_16284\992785954.py:1: SyntaxWarning: invalid escape sequence '\V'
#   df = pd.read_csv('dataset\VRA_20251.csv', skiprows=1, sep=';')

# %%
df.head()
# Out:
#   ICAO Empresa Aérea Número Voo Código Autorização (DI) Código Tipo Linha  \
# 0                AAL       0963                       0                 I
# 1                AAL       0963                       0                 I
# 2                AAL       0963                       0                 I
# 3                AAL       0963                       0                 I
# 4                AAL       0963                       0                 I
#
#   ICAO Aeródromo Origem ICAO Aeródromo Destino     Partida Prevista  \
# 0                  KDFW                   SBGR  2025-01-21 20:25:00
# 1                  KDFW                   SBGR  2025-01-22 20:25:00
# 2                  KDFW                   SBGR  2025-01-23 20:25:00
# 3                  KDFW                   SBGR  2025-01-24 20:25:00
# 4                  KDFW                   SBGR  2025-01-25 20:25:00
#
#           Partida Real     Chegada Prevista         Chegada Real Situação Voo  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89716 entries, 0 to 89715
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ICAO Empresa Aérea       89716 non-null  object
#  1   Número Voo               89716 non-null  object
#  2   Código Autorização (DI)  89716 non-null  object
#  3   Código Tipo Linha        89716 non-null  object
#  4   ICAO Aeródromo Origem    89716 non-null  object
#  5   ICAO Aeródromo Destino   89716 non-null  object
#  6   Partida Prevista         87363 non-null  object
#  7   Partida Real             86361 non-null  object
#  8   Chegada Prevista         87363 non-null  object
#  9   Chegada Real             86361 non-null  object
#  10  Situação Voo             89716 non-null  object
#  11  Código Justificativa     0 non-null      float64
# dtypes: float64(1), object(11)
# memory usage: 8.2+ MB

# %%
df['Situação Voo'].value_counts()
# Out:
# Situação Voo
# REALIZADO        86361
# CANCELADO         3199
# NÃO INFORMADO      156
# Name: count, dtype: int64

# %%
df['Código Tipo Linha'].value_counts()
# Out:
# Código Tipo Linha
# N    71076
# I    14867
# G     1567
# C     1560
# X      646
# Name: count, dtype: int64

# %%
df['Código Autorização (DI)'].value_counts()
# Out:
# Código Autorização (DI)
# 0    86811
# 2      704
# 1      481
# 6      459
# 9      339
# 3      333
# 4      314
# 7      204
# D       56
# E       15
# Name: count, dtype: int64
